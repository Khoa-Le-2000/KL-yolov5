# %% [markdown]
# <a href="https://colab.research.google.com/github/Khoa-Le-2000/KL-yolov5/blob/main/Yolo_V5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Start

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Train-AI/Ver1/
# Out:
# /content/drive/MyDrive/Train-AI/Ver1

# %%
# %ls
# Out:
# coco128/  dataset.zip  exp14/                     VID_20210427_151534_2.mp4
# dataset/  exp13/       VID_20210427_103221_2.mp4  yolov5/

# %%
# %cp -av /content/drive/MyDrive/Train-AI/Ver1/yolov5/ /content/
# %cp -av /content/drive/MyDrive/Train-AI/Ver1/dataset.zip /content/
# Out:
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/' -> '/content/yolov5'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/.gitattributes' -> '/content/yolov5/.gitattributes'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/detect.py' -> '/content/yolov5/detect.py'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/.dockerignore' -> '/content/yolov5/.dockerignore'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/weights' -> '/content/yolov5/weights'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/weights/download_weights.sh' -> '/content/yolov5/weights/download_weights.sh'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/tutorial.ipynb' -> '/content/yolov5/tutorial.ipynb'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/.git' -> '/content/yolov5/.git'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/.git/branches' -> '/content/yolov5/.git/branches'
# '/content/drive/MyDrive/Train-AI/Ver1/yolov5/.git/objects' -> '/content/yolov5/.git/objects'
# ...

# %%
# %cd /content
# %ls
# Out:
# /content
# dataset.zip  drive/  sample_data/  yolov5/

# %%
# !unzip dataset.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: dataset/labels/train/006044.txt
#   inflating: dataset/labels/train/006045.txt
#   inflating: dataset/labels/train/006046.txt
#   inflating: dataset/labels/train/006047.txt
#   inflating: dataset/labels/train/006049.txt
#   inflating: dataset/labels/train/006050.txt
#   inflating: dataset/labels/train/006051.txt
#   inflating: dataset/labels/train/006053.txt
#   inflating: dataset/labels/train/006055.txt
#   inflating: dataset/labels/train/006056.txt
#   inflating: dataset/labels/train/006057.txt
#   inflating: dataset/labels/train/006058.txt
#   inflating: dataset/labels/train/006059.txt
#   inflating: dataset/labels/train/006060.txt
#   inflating: dataset/labels/train/006061.txt
#   inflating: dataset/labels/train/006062.txt
#   inflating: dataset/labels/train/006063.txt
#   inflating: dataset/labels/train/006064.txt
#   inflating: dataset/labels/train/006065.txt
#   inflating: dataset/labels/train/006067.txt
# ...

# %%
# %cd /content/yolov5
# %ls
# Out:
# [Errno 2] No such file or directory: 'yolov5/'
# /content/yolov5
# data/       hubconf.py  __pycache__/      runs/     tutorial.ipynb  yolov5s.pt
# detect.py   LICENSE     README.md         test.py   utils/
# Dockerfile  models/     requirements.txt  train.py  weights/

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/24/33/5568d443ba438d95d4db635dd69958056f087e57e1026bee56f959d53f9d/matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/a5/42/560d269f604d3e186a57c21a363e77e199358d054884e61b73e405dd217c/numpy-1.20.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# ...
#      |████████████████████████████████| 51.0MB 59kB/s
# ...
#      |████████████████████████████████| 3.0MB 49.2MB/s
# Requirement already up-to-date: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (5.4.1)
# ...
#      |████████████████████████████████| 27.4MB 113kB/s
# Requirement already up-to-date: torch>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.8.1+cu101)
# Requirement already up-to-date: torchvision>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (0.9.1+cu101)
# ...

# %%
# !python train.py \
--data data/demo.yaml \
--epochs 300 \
--cfg yolov5s.yaml \
--batch-size 64
# Out:
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 114 (delta 66), reused 78 (delta 59), pack-reused 18
# Receiving objects: 100% (114/114), 69.43 KiB | 7.71 MiB/s, done.
# Resolving deltas: 100% (66/66), completed with 18 local objects.
# From https://github.com/ultralytics/yolov5
#    5189b3a..abfcf9e  master            -> origin/master
#  * [new branch]      Colors            -> origin/Colors
#  * [new branch]      evolve_yolov5m6   -> origin/evolve_yolov5m6
#    0824388..f4fcb23  study_activations -> origin/study_activations
# github: ⚠️ WARNING: code is out of date by 19 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 🚀 v5.0-62-g41cc7ca torch 1.8.1+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# ...

# %%
# %cp -av runs/train/exp14/ /content/drive/MyDrive/Train-AI/Ver1/
# Out:
# 'runs/train/exp14/' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14'
# 'runs/train/exp14/events.out.tfevents.1620142394.b1e4ca680ba4.347.0' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/events.out.tfevents.1620142394.b1e4ca680ba4.347.0'
# 'runs/train/exp14/weights' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/weights'
# 'runs/train/exp14/weights/last.pt' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/weights/last.pt'
# 'runs/train/exp14/weights/best.pt' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/weights/best.pt'
# 'runs/train/exp14/hyp.yaml' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/hyp.yaml'
# 'runs/train/exp14/opt.yaml' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/opt.yaml'
# 'runs/train/exp14/labels_correlogram.jpg' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/labels_correlogram.jpg'
# 'runs/train/exp14/labels.jpg' -> '/content/drive/MyDrive/Train-AI/Ver1/exp14/labels.jpg'
# ...

# %%
# %cp -av /content/drive/MyDrive/Train-AI/VID_20210427_103221_2.mp4 /content/
# Out:
# '/content/drive/MyDrive/Train-AI/VID_20210427_103221_2.mp4' -> '/content/VID_20210427_103221_2.mp4'

# %%
# !python detect.py \
--source /content/VID_20210427_103221_2.mp4 \
--weights runs/train/exp14/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/VID_20210427_103221_2.mp4', update=False, view_img=False, weights=['runs/train/exp14/weights/best.pt'])
# YOLOv5 🚀 v5.0-62-g41cc7ca torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7105153 parameters, 0 gradients, 16.5 GFLOPS
# video 1/1 (1/4201) /content/VID_20210427_103221_2.mp4: 384x640 3 cars, 2 motorbikes, Done. (0.011s)
# video 1/1 (2/4201) /content/VID_20210427_103221_2.mp4: 384x640 2 cars, 2 motorbikes, Done. (0.011s)
# video 1/1 (3/4201) /content/VID_20210427_103221_2.mp4: 384x640 2 cars, 2 motorbikes, Done. (0.011s)
# video 1/1 (4/4201) /content/VID_20210427_103221_2.mp4: 384x640 2 cars, 2 motorbikes, Done. (0.011s)
# ...

# %%
# %cp -av runs/detect/exp4/VID_20210427_103221_2.mp4 /content/drive/MyDrive/Train-AI/Ver1/
# Out:
# 'runs/detect/exp4/VID_20210427_103221_2.mp4' -> '/content/drive/MyDrive/Train-AI/Ver1/VID_20210427_103221_2.mp4'
